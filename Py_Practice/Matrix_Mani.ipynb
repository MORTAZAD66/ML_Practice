# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randn(1000000, 2)
print(x)
# Out:
# [[ 0.46088906 -0.39509921]
#  [ 1.81938814 -2.83729734]
#  [-1.21147087  1.28889652]
#  ...
#  [ 2.31973411 -0.11206665]
#  [-0.81101175 -0.37579599]
#  [ 2.11232151 -0.05608757]]

# %%
plt.subplot(1,2,1)
plt.hist(x, bins=500)
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,2)
plt.hist(x, bins=50)
plt.show()

# %% [markdown]
# # 3D Plots

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.arange(-10, 10., 0.5)
y = np.arange(-10, 10., 0.5)
X, Y = np.meshgrid(x, y)
Z = X ** 2 + Y ** 2

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.rainbow)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# /tmp/ipykernel_18685/3707014594.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.gca(projection='3d')
#surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.Dark2)
cset = ax.contour(X, Y, Z, zdir='z', offset=0, cmap=plt.cm.Dark2)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# /tmp/ipykernel_18685/4025547711.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# /tmp/ipykernel_18685/4025547711.py:5: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)
